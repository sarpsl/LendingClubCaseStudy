# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan.csv')
df.head()
# Out:
# C:\Users\ASyed\AppData\Local\Temp\ipykernel_128812\3318210521.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
df.loan_status
# Out:
# 0         Fully Paid
# 1        Charged Off
# 2         Fully Paid
# 3         Fully Paid
# 4            Current
#             ...
# 39712     Fully Paid
# 39713     Fully Paid
# 39714     Fully Paid
# 39715     Fully Paid
# 39716     Fully Paid
# Name: loan_status, Length: 39717, dtype: object

# %%
df[(df.values.ravel() == 'Charged Off').reshape(df.shape).any(1)]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1      1077430    1314167       2500         2500           2500.0
# 8      1071795    1306957       5600         5600           5600.0
# 9      1071570    1306721       5375         5375           5350.0
# 12     1064687    1298717       9000         9000           9000.0
# 14     1069057    1303503      10000        10000          10000.0
# ...        ...        ...        ...          ...              ...
# 39667   118823     118026       2500         2500            675.0
# 39668   118533     117783       2500         2500            825.0
# 39669   118523     118519       6500         6500            225.0
# 39678   113179     113093       1000         1000            950.0
# 39688   111227     111223      20000        20000           2800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 1       60 months   15.27%        59.83     C        C4  ...
# ...

# %%
print(df.isnull().sum())
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.dtypes
# Out:
# id                              int64
# member_id                       int64
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
#                                ...
# tax_liens                     float64
# tot_hi_cred_lim               float64
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# Length: 111, dtype: object

# %%
np.version.version
# Out:
# '1.24.3'

# %%
# !python --version
# Out:
# Python 3.9.17

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-client               1.12.0
# anaconda-navigator            2.2.0
# anyio                         3.5.0
# AnyQt                         0.1.1
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# ...

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.12.2
# ipykernel        : 6.25.0
# ipywidgets       : 8.0.4
# jupyter_client   : 7.4.9
# jupyter_core     : 5.3.0
# jupyter_server   : 1.23.4
# jupyterlab       : 3.6.3
# nbclient         : 0.5.13
# nbconvert        : 6.5.4
# nbformat         : 5.7.0
# notebook         : 6.5.4
# qtconsole        : 5.4.2
# traitlets        : 5.7.1
